# %% [markdown]
# # Board Generation

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from pupil_apriltags import Detector
from moms_apriltag import board

# %%
family = "tag36h11"
shape = (6,8)
size = 50

tgt = board(shape, family, size)

plt.imshow(tgt, cmap="gray")
plt.axis("off");
