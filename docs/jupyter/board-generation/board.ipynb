# %% [markdown]
# ![](../header.jpg)
#
# # Generating a Board with Apriltags
#
# Kevin J. Walchko
#
# ---

# %%
# reload library
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt
from moms_apriltag import ApriltagBoard

# %%
board = ApriltagBoard.create(4,6,"tag25h9", 0.02)
# print(board.draw)
tgt = board.board
print(tgt.shape)
print(np.max(tgt), np.min(tgt))

plt.imshow(tgt, cmap="gray")
plt.axis("off")
plt.title(f"{tgt.shape} {board.family}")
# Out:
# (1520, 2240)
# 255 0
# Text(0.5, 1.0, '(1520, 2240) tag25h9')

# %%
board.objPoints
# Out:
# {0: array([[0.02571429, 0.02571429, 0.        ],
#         [0.02571429, 0.00571429, 0.        ],
#         [0.00571429, 0.00571429, 0.        ],
#         [0.00571429, 0.02571429, 0.        ]]),
#  1: array([[0.02571429, 0.05142857, 0.        ],
#         [0.02571429, 0.03142857, 0.        ],
#         [0.00571429, 0.03142857, 0.        ],
#         [0.00571429, 0.05142857, 0.        ]]),
#  2: array([[0.02571429, 0.07714286, 0.        ],
#         [0.02571429, 0.05714286, 0.        ],
#         [0.00571429, 0.05714286, 0.        ],
#         [0.00571429, 0.07714286, 0.        ]]),
#  3: array([[0.02571429, 0.10285714, 0.        ],
#         [0.02571429, 0.08285714, 0.        ],
#         [0.00571429, 0.08285714, 0.        ],
#         [0.00571429, 0.10285714, 0.        ]]),
#  4: array([[0.02571429, 0.12857143, 0.        ],
#         [0.02571429, 0.10857143, 0.        ],
#         [0.00571429, 0.10857143, 0.        ],
#         [0.00571429, 0.12857143, 0.        ]]),
# ...

# %%
tag = board.getTag(12)

plt.imshow(tag, cmap="gray")
plt.axis("off")
plt.title(f"{board.family} 12");

# %%
a = {"a":1,"b":2}
list(a.keys())
# Out:
# ['a', 'b']
